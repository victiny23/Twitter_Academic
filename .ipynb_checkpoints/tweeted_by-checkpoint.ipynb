# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Times New Roman'

# %%
papers = pd.read_csv('papers.csv', index_col=0)
papers
# Out:
#                                                  title  cited_by  year
# 0    Optimal control analysis of a mathematical mod...        20  2018
# 1    Modeling combination therapy for breast cancer...        26  2018
# 2     Serum upar as biomarker in breast cancer recu...         8  2016
# 3     Consolidated mathematical growth model of the...         5  2018
# 4    Analysis of a breast cancer mathematical model...         0  2020
# ..                                                 ...       ...   ...
# 486  Network modularity and hierarchical structure ...         8  2018
# 487   Validating a breast cancer score in Spanish w...         5  2018
# 488  Towards breast cancer rotational radiotherapy ...         1  2016
# 489  NCCN guidelines insights: breast cancer, versi...       256  2017
# 490  Using â€˜ Costs Statesâ€™ in a Semi-Markov Mod...         0  2020
#
# [491 rows x 3 columns]

# %%
tweet_counts = []
for title in papers.title:
    title_comm = '"'+ title + '"'
    tweet_ids = !snscrape twitter-search {title_comm}
    tweet_count = len(tweet_ids)
    tweet_counts.append(tweet_count)

# %%
papers['tweeted_by'] = tweet_counts
papers.to_csv('papers+.csv')

# %%
papers.sort_values(by='tweeted_by', ascending=False)
# Out:
#                                                  title  cited_by  year  \
# 221  International evaluation of an AI system for b...       231  2020
# 64              Breast cancer screening in young women        19  2018
# 189               Systems approaches to cancer biology        13  2016
# 208               The Natural History of Breast Cancer         2  2017
# 251          Artificial intelligence in breast imaging        32  2019
# ..                                                 ...       ...   ...
# 206  Inference of protein-protein networks for trip...         0  2018
# 204  Modeling treatment of cancer using oncolytic v...         1  2020
# 203  Performance evaluation of extended EXACT algor...      2016  2016
# 202   Personalized breast cancer screening strategi...         5  2019
# 490  Using â€˜ Costs Statesâ€™ in a Semi-Markov Mod...         0  2020
#
#      tweeted_by
# 221         146
# 64          112
# 189         111
# 208          68
# 251          42
# ...

# %%
papers = papers[papers.year>2015]
papers.year.value_counts()
# Out:
# 2020    116
# 2019    105
# 2017     99
# 2018     98
# 2016     66
# Name: year, dtype: int64

# %%
sns.distplot(papers.cited_by)

# %%
sns.distplot(papers.cited_by[papers.cited_by<100])

# %%
sns.distplot(papers.tweeted_by)

# %%
sns.distplot(papers.tweeted_by[papers.tweeted_by<10])

# %%
papers.astype({'year': 'int64'}).dtypes
# Out:
# title         object
# cited_by       int64
# year           int64
# tweeted_by     int64
# dtype: object

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)
papers_1 = papers[papers.cited_by<100]
papers_2 = papers_1[papers_1.tweeted_by<10]
sns.scatterplot(data=papers_2, x='tweeted_by', y='cited_by', hue='year', palette=sns.color_palette("Set1", 5))
#ax.set_xlim(xmin=-.1, xmax=10)
#ax.set_ylim(ymin=0, ymax=100)
plt.xlabel('Number of tweets', fontsize=25)
plt.ylabel('Number of citations', fontsize=25)
plt.tick_params(axis='both', labelsize=20)
plt.legend(loc='upper right', fontsize=20)

# %%
fig = plt.figure(figsize=(12, 8))
width = 1
#plt.bar(papers_3.index, papers_3.cited_by, width=width)
#plt.bar(papers_3.index + width/2, papers_3.tweeted_by, width=width)
plt.plot(papers_2.index, papers_2.cited_by)
plt.plot(papers_2.index, papers_2.tweeted_by)
plt.legend(['Number of citations', 'Number of tweets'], loc='upper right', fontsize=20)
plt.xlabel('Article Number', fontsize=25)
plt.ylabel('Impact', fontsize=25)
plt.tick_params(axis='both', labelsize=20)

# %%
years = np.arange(2016, 2021)
fig = plt.figure(figsize=(12, 8))
width=0.4
plt.bar(years-width/2, papers_2.groupby('year').cited_by.mean(), width)
plt.bar(years+width/2, papers_2.groupby('year').tweeted_by.mean(), width)
plt.legend(['Number of citations', 'Number of tweets'], loc='upper right', fontsize=20)
plt.xlabel('Year', fontsize=25)
plt.ylabel('Impact', fontsize=25)
plt.tick_params(axis='both', labelsize=20)

# %%
papers_2.groupby('year').cited_by.mean()
# Out:
# year
# 2016    22.237288
# 2017    18.836957
# 2018    13.436170
# 2019    11.735294
# 2020     0.772727
# Name: cited_by, dtype: float64
