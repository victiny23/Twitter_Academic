# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Times New Roman'
import requests
import time

from bs4 import BeautifulSoup as bs

proxies[0] = {
  'http': 'http://syvoxapu:24elY0vz4V@81.90.176.19:47147',
}

proxies[1] = {
    'http': 'http://syvoxapu:24elY0vz4V@81.90.176.11:39855',
}
proxies[2] = {
    'http': 'http://syvoxapu:24elY0vz4V@81.90.176.25:40369',
}

# %%
titles = []
cite_counts = []
years = []
for page in range(50):
    start_num = page*10
    url = "https://scholar.google.com/scholar?start=" + str(start_num) + "&q=mathematical+model+breast+cancer&hl=en&as_sdt=1,44&as_ylo=2016"
    html_data = requests.get(url,proxies=proxies[page%3])
    soup = bs(html_data.content, 'html.parser')
    time.sleep(1)
    for i in range(len(soup.findAll(class_='gs_rt'))):
        title = soup.findAll(class_='gs_rt')[i].text
        title_clean = title.replace('[HTML]', '').replace('[PDF]', '')
        if [int(j) for  j in title.split() if j.isdigit()]:
            continue
        citation = soup.findAll(class_='gs_ri')[i].text
        if not [int(k) for  k in citation.split() if k.isdigit()]:
            year = 0
        else:
            year = [int(k) for  k in citation.split() if k.isdigit()][0]
        cite_count = 0
        if "Cited" in citation.split():
            cite_count = [int(k) for  k in citation.split() if k.isdigit()][-2]
        titles.append(title_clean)
        cite_counts.append(cite_count)
        years.append(year)
papers = pd.DataFrame({'title': titles, 'cited_by': cite_counts, 'year': years})
papers
# Out:
#                                                  title  cited_by  year
# 0    Optimal control analysis of a mathematical mod...        20  2018
# 1    Modeling combination therapy for breast cancer...        26  2018
# 2     Serum upar as biomarker in breast cancer recu...         8  2016
# 3     Consolidated mathematical growth model of the...         5  2018
# 4    Analysis of a breast cancer mathematical model...         0  2020
# ..                                                 ...       ...   ...
# 486  Network modularity and hierarchical structure ...         8  2018
# 487   Validating a breast cancer score in Spanish w...         5  2018
# 488  Towards breast cancer rotational radiotherapy ...         1  2016
# 489  NCCN guidelines insights: breast cancer, versi...       256  2017
# 490  Using â€˜ Costs Statesâ€™ in a Semi-Markov Mod...         0  2020
#
# [491 rows x 3 columns]

# %%
papers.to_csv('papers.csv')
